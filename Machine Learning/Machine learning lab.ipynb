# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\Rand Rothstein\Desktop\titanic.csv")

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(data.nunique)
# Out:
# <bound method DataFrame.nunique of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
print(data.info)
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
from sklearn.model_selection import train_test_split
training,testing=train_test_split(data,test_size=0.30,random_state=24)

# %%
training.shape
# Out:
# (623, 12)

# %%
testing.shape
# Out:
# (268, 12)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, metrics
  
# load the boston dataset
boston = datasets.load_boston(return_X_y=False)
  
# defining feature matrix(X) and response vector(y)
X = boston.data
y = boston.target
  
# splitting X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4,
                                                    random_state=1)
  
# create linear regression object
reg = linear_model.LinearRegression()
  
# train the model using the training sets
reg.fit(X_train, y_train)
  
# regression coefficients
print('Coefficients: ', reg.coef_)
  
# variance score: 1 means perfect prediction
print('Variance score: {}'.format(reg.score(X_test, y_test)))
  
# plot for residual error
  
## setting plot style
plt.style.use('fivethirtyeight')
  
## plotting residual errors in training data
plt.scatter(reg.predict(X_train), reg.predict(X_train) - y_train,
            color = "green", s = 10, label = 'Train data')
  
## plotting residual errors in test data
plt.scatter(reg.predict(X_test), reg.predict(X_test) - y_test,
            color = "blue", s = 10, label = 'Test data')
  
## plotting line for zero residual error
plt.hlines(y = 0, xmin = 0, xmax = 50, linewidth = 2)
  
## plotting legend
plt.legend(loc = 'upper right')
  
## plot title
plt.title("Residual errors")
  
## method call for showing the plot
plt.show()

# %% [markdown]
# # Linear Regression

# %%
from sklearn.model_selection import train_test.split
sklearn_split dat into taraing_test
# Out:
#   File "<ipython-input-16-23bda0c68d04>", line 1
#     from sklearn.model_selection import train_test.split
#                                                   ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

melbourne_file_path = '../input/melbourne-housing-snapshot/melb_data.csv'
melbourne_data = pd.read_csv(melbourne_file_path) 
melbourne_data.columns
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-0944da836eaa> in <module>
#       2
#       3 melbourne_file_path = '../input/melbourne-housing-snapshot/melb_data.csv'
# ----> 4 melbourne_data = pd.read_csv(melbourne_file_path)
#       5 melbourne_data.columns
#
# ...

# %%
melbourne_data = pd.read_csv(r"C:\Users\Rand Rothstein\Desktop\melb_data.csv") 
melbourne_data.columns

# %%
melbourne_data.isnull().sum()
melbourne_data.columns

# %%
melbourne_data=melbourne_data.dropna(axis=0)
melbourne_data.describe()

# %%
y=melbourne_data.Price

# %%
y.head()

# %%
melbourne_features = ['Rooms','Bathroom','Landsize',
                      'Lattitude','Longtitude']

# %%
 x=melbourne_data[melbourne_features]
x.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-1168901a02c7> in <module>
# ----> 1 x=melbourne_data[melbourne_features]
#       2 x.info()
#
# NameError: name 'melbourne_data' is not defined

# %%
#Building Your Model
#sklearn is easily the most popular library for modeling the types of data
from sklearn.tree import DecisionTreeRegressor
melbourne_model = DecisionTreeRegressor(random_state=1)
melbourne_model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c529d90ddee8> in <module>
#       3 from sklearn.tree import DecisionTreeRegressor
#       4 melbourne_model = DecisionTreeRegressor(random_state=1)
# ----> 5 melbourne_model.fit(x,y)
#
# NameError: name 'x' is not defined

# %%
pip install tensor
import tensor as tf
# Out:
#   File "<ipython-input-3-d1c5dcce257f>", line 1
#     pip install tensor
#         ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-73f982c7f466> in <module>
# ----> 1 tensor
#
# NameError: name 'tensor' is not defined
