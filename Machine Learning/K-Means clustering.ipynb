# %%
# kmeans look for the distance between centroid and the point and repeasts until does not change [Wcss]
#kmeans++ is weighted random to solve random insilization trap
# Step involves creating dependent variable
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv(r"C:\Users\Rand Rothstein\Desktop\Machine Learning A-Z (Codes and Datasets)\Part 4 - Clustering\Section 24 - K-Means Clustering\Python\Mall_Customers.csv")
# x=dataset.iloc[:, 1:5].values
x=dataset.iloc[:, [3,4]].values
# x= np.array(x).reshape(-1, 1)
print(x)
# Out:
# [[ 15  39]
#  [ 15  81]
#  [ 16   6]
#  [ 16  77]
#  [ 17  40]
#  [ 17  76]
#  [ 18   6]
#  [ 18  94]
#  [ 19   3]
#  [ 19  72]
#  [ 19  14]
#  [ 19  99]
#  [ 20  15]
#  [ 20  77]
#  [ 20  13]
#  [ 20  79]
#  [ 21  35]
#  [ 21  66]
#  [ 23  29]
#  [ 23  98]
#  [ 24  35]
#  [ 24  73]
#  [ 25   5]
#  [ 25  73]
#  [ 28  14]
#  [ 28  82]
#  [ 28  32]
#  [ 28  61]
#  [ 29  31]
#  [ 29  87]
#  [ 30   4]
#  [ 30  73]
#  [ 33   4]
#  [ 33  92]
#  [ 33  14]
#  [ 33  81]
#  [ 34  17]
#  [ 34  73]
#  [ 37  26]
#  [ 37  75]
#  [ 38  35]
#  [ 38  92]
#  [ 39  36]
#  [ 39  61]
#  [ 39  28]
#  [ 39  65]
#  [ 40  55]
#  [ 40  47]
#  [ 40  42]
#  [ 40  42]
#  [ 42  52]
#  [ 42  60]
#  [ 43  54]
#  [ 43  60]
#  [ 43  45]
#  [ 43  41]
#  [ 44  50]
#  [ 44  46]
#  [ 46  51]
#  [ 46  46]
#  [ 46  56]
#  [ 46  55]
#  [ 47  52]
#  [ 47  59]
#  [ 48  51]
#  [ 48  59]
#  [ 48  50]
#  [ 48  48]
#  [ 48  59]
#  [ 48  47]
#  [ 49  55]
#  [ 49  42]
#  [ 50  49]
#  [ 50  56]
#  [ 54  47]
#  [ 54  54]
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
# print(x[:,0])

# %%
# from sklearn.preprocessing import LabelEncoder
# le=LabelEncoder()
# x[:,0]=le.fit_transform(x[:,0])

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,100):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans.fit(x,y)
    wcss.append(kmeans.inertia_)      # it returns the sum of distance between all the points to the centroid

# plt.plot(range(1,100),wcss)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-647124e9105b> in <module>
#       3 for i in range(1,100):
#       4     kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
# ----> 5     kmeans.fit(x,y)
#       6     wcss.append(kmeans.inertia_)      # it returns the sum of distance between all the points to the centroid
#       7
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#    1006         """
#    1007         n_samples = X.shape[0]
# -> 1008         n_clusters = self.n_clusters if n_centroids is None else n_centroids
#    1009
#    1010         if init_size is not None and init_size < n_samples:
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in _check_mkl_vcomp(self, X, n_samples)
#     872
#     873         # n-init
# --> 874         # TODO(1.4): Remove
# ...

# %%
# !pip install --upgrade scikit-learn
# Out:
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.0.1
#     Uninstalling joblib-1.0.1:
#       Successfully uninstalled joblib-1.0.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.1
#     Uninstalling scikit-learn-0.24.1:
#       Successfully uninstalled scikit-learn-0.24.1
# ...

# %%
x = [4, 5, 10, 4, 3, 11, 14 , 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]
data = list(zip(x))
print(data)
# Out:
# [(4,), (5,), (10,), (4,), (3,), (11,), (14,), (6,), (10,), (12,)]
